# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import unicodedata
# %matplotlib inline

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
html = urlopen("http://www.htfc.com/main/a/20170619/80000072.shtml")
bsObj = BeautifulSoup(html.read(),'lxml')

# %%
newData = pd.DataFrame()
i = 1
flag = 0
tickdict = []
newData = pd.DataFrame()
nameList = bsObj.findAll("span", {"style":"FONT-FAMILY: 仿宋,仿宋_GB2312"})
if nameList == []:
    print(1)
    nameList = bsObj.findAll("span", {"style":"font-family:仿宋,仿宋_GB2312"})
# if nameList == []:
#     print(1)
#     nameList = bsObj.findAll("span", {"style":"font-family:仿宋,仿宋_GB2312"})
for name in nameList:
    #print(name.get_text().strip(),1)
    #if name.get_text().strip() == "上海期货交易所:" or flag == 1: #or (name.get_text().strip()[0] == "铜" or ""):
        #if name.get_text().strip() == "上海期货交易所:":
            #flag = 1
    if name.get_text().strip() not in ["上海期货交易所:","郑州商品交易所:",
                               "大连商品交易所（交割月份的涨跌停板幅度为上一交易日结算价的6%）:",
                               "大连商品交易所:","中国金融期货交易所:"]:
        m = name.get_text().strip()
        if m.strip() not in ['','5','10']:
            m = unicodedata.normalize("NFKD", m) ## https://stackoverflow.com/questions/10993612/python-removing-xa0-from-string
            m.split(maxsplit=1)
            print(m)
            tickdict.append(m)

NewData = pd.DataFrame(tickdict)
NewData = NewData[len(NewData) - 102:].reset_index(drop=True)// 因为

s = NewData[0].apply(lambda x: x.split(':'))
##df = pd.DataFrame(s)
NewData['Code'],NewData['Limit'] = zip(*NewData[0].apply(lambda x: x.split(':',maxsplit = 1)))

NewData["Comments"] = ""
NewData['Name'] = ""

for i in range(len(NewData)):
    NewData['Limit'].iloc[i] = NewData['Limit'].iloc[i].strip()

for i in range(len(NewData)):
    NewData['Name'].iloc[i] = (NewData['Code'].iloc[i])[:-2].strip().replace(' ','')
    NewData['Code'].iloc[i] = (NewData['Code'].iloc[i])[-2:].strip()
    ##print((NewData['Tick'].iloc[i])[:-2])
    if len(NewData['Limit'].iloc[i]) > 6:
        NewData['Limit'].iloc[i],NewData['Comments'].iloc[i] = NewData['Limit'].iloc[i].split('(',maxsplit = 1)
        #if len(NewData['C'].iloc[i]) > 2:
        NewData['Comments'].iloc[i] = NewData['Comments'].iloc[i].replace('(','').replace(')','')
del NewData[0]


NewData['Margin'] = ""
NewData['Margin Comments'] = ""
# for item in list(NewData['Name']):
# #NewData[NewData['Name'] == item]
# #df.loc[df['column_name'] == some_value]
# NewData.loc[NewData['Name'] == item])
list_tick = NewData.set_index('Name').index.get_duplicates()
#NewData[NewData['Name'] == list_tick[0]].Limit.index[]
for i in range(len(list_tick)):
    pos = NewData[NewData['Name'] == list_tick[i]].Limit.index[0]
    
    NewData['Margin'].iloc[pos] = NewData[NewData['Name'] == list_tick[i]].Limit.values[1]
    NewData['Margin Comments'].iloc[pos] = NewData[NewData['Name'] == list_tick[i]].Comments.values[1]
NewData = NewData[['Name', 'Code', 'Limit','Comments','Margin', 'Margin Comments']]
NewData = NewData.iloc[:49]
NewData.to_csv('DailyContractsInformation.csv',encoding='utf_8_sig')
# Out:
# 1
# 新合约:
# SR1805C6100
# SR1805P6100
# SR1807C6100
# SR1807P6100
# SR1811C6100
# SR1811P6100
# 铜
# cu:6%
# 铝       al:6% (其中:al1806 12%(新合约))
# 锌       zn:6% (其中:zn1806 12%(新合约))
# 铅       pb:6%
# 镍       ni:6%
# 锡       sn:6% (其中:sn1712、1804、1806 12%(新合约))
# 黄金     au:5% (其中:au1709 10%(新合约))
# 白银     ag:5%
# 螺纹钢   rb:7%
# 线  材   wr:5% (其中:wr1706-1709、1711、1801-1806
# 10%(新合约))
# 热轧卷板 hc:6% (其中:hc1806 12%(新合约))
# 燃料油   fu:5% (其中:fu1707、1710、1712、1803、1805-1806 10%(新合约))
# 石油沥青 bu:6%
# 橡  胶   ru:7% (其中:ru1806 14%(新合约))
# 黄大豆    a:5% (其中:a1811 8%(新合约))
# 黄豆二    b:4% (其中:b1806 8%(新合约))
# 胶合板   bb:5% (其中:bb1801-1803、1805-1806 8%(新合约))
# 玉  米    c:5%
# 玉米淀粉 cs:5%
# 纤维板   fb:5% (其中:fb1706-1707、1710-1806 8%(新合约))
# 铁矿石    i:8% (其中:i1806 8%(新合约))
# 焦  炭    j:8% (其中:j1806 8%(新合约))
# 鲜鸡蛋   jd:5% (其中:jd1706 9%(第一个涨停))
# 焦  煤   jm:8% (其中:jm1804、1806 8%(新合约))
# 聚乙烯    l:5% (其中:l1804、1806 8%(新合约))
# 豆  粕    m:5%
# 棕榈油    p:5% (其中:p1806 8%(新合约))
# 聚丙烯   pp:5% (其中:pp1806 8%(新合约))
# 聚氯乙烯  v:5% (其中:v1711、1803、1806 8%(新合约))
# 豆  油    y:5%
# 棉  花   CF:5%
# 玻  璃   FG:5%
# 粳  稻   JR:4% (其中:JR1707、1803、1805 8%(新合约))
# 晚籼稻   LR:4% (其中:LR1707、1801、1803、1805 8%(新合约))
# 甲  醇   MA:5% (其中:MA1806 10%(新合约))
# 菜籽油   OI:5%
# 普  麦   PM:4% (其中:PM1711、1803、1805
# 8%(新合约))
# 早籼稻   RI:4% (其中:RI1711、1803、1805 8%(新合约))
# 菜籽粕   RM:5%
# 油菜籽   RS:10%
# 硅  铁   SF:5% (其中:SF1803-1804、1806 10%(新合约))
# 锰  硅   SM:6% (其中:SM1711、1803-1804、1806
# 12%(新合约))
# 白  糖   SR:4%
# 精对苯二甲酸 TA:5%
# 强  麦   WH:5%
# 动力煤   ZC:6%(其中:ZC1803、1806 12%(新合约))
# 股指沪深300 IF: 10%
# 上证50指数  IH: 10%
# 中证500指数 IC: 10%
# 年期国债   TF:1.2%
# 年期国债   T:  2%
# 白银    ag:14% (其中:ag1707 17%)
# 铝
# al:13% (其中:al1707 15%)
# 黄金    au:13% (其中:au1707 17%)
# 石油沥青bu:14% (其中:bu1707 16%)
# 铜      cu:14% (其中:cu1707
# 16%)
# 燃料油  fu:25%
# 热轧卷板hc:14% (其中:hc1707 16%)
# 镍
# ni:14% (其中:ni1707 16% ni1709 16%(持仓超36万))
# 铅      pb:13% (其中:pb1707
# 15%)
# 螺纹钢  rb:15% (其中:rb1707 16%)
# 橡胶    ru:15% (其中:ru1707 16% ru1709 18%(持仓超16万))
# 锡
# sn:13% (其中:sn1707 15%)
# 线材    wr:24%
# 锌      zn:14% (其中:zn1707
# 16%)
# 黄大豆   a:12%
# 黄豆二   b:25%
# 胶合板  bb:25%
# 玉  米   c:12%
# 玉米淀粉cs:12%
# 纤维板  fb:25%
# 铁矿石   i:16%
# 焦  炭   j:16%
# 鲜鸡蛋  jd:13% (其中:jd1706 25%)
# 焦  煤  jm:16%
# 聚乙烯   l:12%
# 豆  粕   m:12%
# 棕榈油   p:12%
# 聚丙烯  pp:12%
# 聚氯乙烯 v:12%
# 豆  油   y:12%
# 棉  花  CF:12% (其中:CF1707 15%)
# 玻  璃  FG:13% (其中:FG1707 16%)
# 粳  稻  JR:25% (其中:JR1707 30%)
# 晚籼稻  LR:25% (其中:LR1707 30%)
# 甲  醇  MA:12% (其中:MA1707 15%)
# 菜籽油  OI:12% (其中:OI1707 15%)
# 普  麦  PM:25% (其中:PM1707 30%)
# 早籼稻  RI:25% (其中:RI1707 30%)
# 菜籽粕  RM:11% (其中:RM1707 15%)
# 油菜籽  RS:25%
# 硅  铁  SF:14% (其中:SF1707 17%)
# 锰  硅  SM:14% (其中:SM1707 17%)
# 白  糖  SR:10% (其中:SR1707 15%)
# 精对苯二甲酸 TA:11% (其中:TA1707 15%)
# 强  麦  WH:11% (其中:WH1707 14%)
# 动力煤  ZC:14% (其中:ZC1707 16%)
# 股指沪深300 IF: 22%
# 上证50指数  IH: 22%
# 中证500指数 IC: 32%(其中:IC套保 22%)
# 年期国债   TF:2.2%
# 年期国债   T:  3%

# %%
NewData
# Out:
#                                                      0
# 0                                       铜      \ncu:6%
# 1                   铝       al:6% (其中:al1806 12%(新合约))
# 2                   锌       zn:6% (其中:zn1806 12%(新合约))
# 3                                        铅       pb:6%
# 4                                        镍       ni:6%
# 5         锡       sn:6% (其中:sn1712、1804、1806 12%(新合约))
# 6                    黄金     au:5% (其中:au1709 10%(新合约))
# 7                                         白银     ag:5%
# 8                                          螺纹钢   rb:7%
# 9    线  材   wr:5% (其中:wr1706-1709、1711、1801-1806\n1...
# 10                     热轧卷板 hc:6% (其中:hc1806 12%(新合约))
# 11   燃料油   fu:5% (其中:fu1707、1710、1712、1803、1805-180...
# 12                                          石油沥青 bu:6%
# 13                   橡  胶   ru:7% (其中:ru1806 14%(新合约))
# 14                      黄大豆    a:5% (其中:a1811 8%(新合约))
# 15                      黄豆二    b:4% (其中:b1806 8%(新合约))
# 16      胶合板   bb:5% (其中:bb1801-1803、1805-1806 8%(新合约))
# 17                                        玉  米    c:5%
# 18                                          玉米淀粉 cs:5%
# 19      纤维板   fb:5% (其中:fb1706-1707、1710-1806 8%(新合约))
# 20                      铁矿石    i:8% (其中:i1806 8%(新合约))
# 21                     焦  炭    j:8% (其中:j1806 8%(新合约))
# 22                   鲜鸡蛋   jd:5% (其中:jd1706 9%(第一个涨停))
# 23               焦  煤   jm:8% (其中:jm1804、1806 8%(新合约))
# 24                 聚乙烯    l:5% (其中:l1804、1806 8%(新合约))
# 25                                        豆  粕    m:5%
# 26                      棕榈油    p:5% (其中:p1806 8%(新合约))
# 27                     聚丙烯   pp:5% (其中:pp1806 8%(新合约))
# 28             聚氯乙烯  v:5% (其中:v1711、1803、1806 8%(新合约))
# 29                                        豆  油    y:5%
# ..                                                 ...
# 72                                        焦  炭   j:16%
# 73                         鲜鸡蛋  jd:13% (其中:jd1706 25%)
# 74                                        焦  煤  jm:16%
# 75                                         聚乙烯   l:12%
# 76                                        豆  粕   m:12%
# 77                                         棕榈油   p:12%
# 78                                         聚丙烯  pp:12%
# 79                                          聚氯乙烯 v:12%
# 80                                        豆  油   y:12%
# 81                        棉  花  CF:12% (其中:CF1707 15%)
# 82                        玻  璃  FG:13% (其中:FG1707 16%)
# 83                        粳  稻  JR:25% (其中:JR1707 30%)
# 84                         晚籼稻  LR:25% (其中:LR1707 30%)
# 85                        甲  醇  MA:12% (其中:MA1707 15%)
# 86                         菜籽油  OI:12% (其中:OI1707 15%)
# 87                        普  麦  PM:25% (其中:PM1707 30%)
# 88                         早籼稻  RI:25% (其中:RI1707 30%)
# 89                         菜籽粕  RM:11% (其中:RM1707 15%)
# 90                                         油菜籽  RS:25%
# 91                        硅  铁  SF:14% (其中:SF1707 17%)
# 92                        锰  硅  SM:14% (其中:SM1707 17%)
# 93                        白  糖  SR:10% (其中:SR1707 15%)
# 94                       精对苯二甲酸 TA:11% (其中:TA1707 15%)
# 95                        强  麦  WH:11% (其中:WH1707 14%)
# 96                         动力煤  ZC:14% (其中:ZC1707 16%)
# 97                                     股指沪深300 IF: 22%
# 98                                     上证50指数  IH: 22%
# 99                        中证500指数 IC: 32%(其中:IC套保 22%)
# 100                                     年期国债   TF:2.2%
# 101                                      年期国债   T:  3%
#
# [102 rows x 1 columns]

# %%
s = NewData[0].apply(lambda x: x.split(':'))
##df = pd.DataFrame(s)
NewData['Code'],NewData['Limit'] = zip(*NewData[0].apply(lambda x: x.split(':',maxsplit = 1)))

NewData["Comments"] = ""
NewData['Name'] = ""

for i in range(len(NewData)):
    NewData['Limit'].iloc[i] = NewData['Limit'].iloc[i].strip()

for i in range(len(NewData)):
    NewData['Name'].iloc[i] = (NewData['Code'].iloc[i])[:-2].strip().replace(' ','')
    NewData['Code'].iloc[i] = (NewData['Code'].iloc[i])[-2:].strip()
    ##print((NewData['Tick'].iloc[i])[:-2])
    if len(NewData['Limit'].iloc[i]) > 6:
        NewData['Limit'].iloc[i],NewData['Comments'].iloc[i] = NewData['Limit'].iloc[i].split('(',maxsplit = 1)
        #if len(NewData['C'].iloc[i]) > 2:
        NewData['Comments'].iloc[i] = NewData['Comments'].iloc[i].replace('(','').replace(')','')
del NewData[0]


NewData['Margin'] = ""
NewData['Margin Comments'] = ""
# for item in list(NewData['Name']):
# #NewData[NewData['Name'] == item]
# #df.loc[df['column_name'] == some_value]
# NewData.loc[NewData['Name'] == item])
list_tick = NewData.set_index('Name').index.get_duplicates()
#NewData[NewData['Name'] == list_tick[0]].Limit.index[]
for i in range(len(list_tick)):
    pos = NewData[NewData['Name'] == list_tick[i]].Limit.index[0]
    
    NewData['Margin'].iloc[pos] = NewData[NewData['Name'] == list_tick[i]].Limit.values[1]
    NewData['Margin Comments'].iloc[pos] = NewData[NewData['Name'] == list_tick[i]].Comments.values[1]
NewData = NewData[['Name', 'Code', 'Limit','Comments','Margin', 'Margin Comments']]
NewData = NewData.iloc[:49]
NewData.to_csv('DailyContractsInformation.csv',encoding='utf_8_sig')

# %%
NewData
# Out:
#        Name Code Limit                                   Comments Margin  \
# 0         铜   cu    6%                                              14%
# 1         铝   al   6%                            其中:al1806 12%新合约   13%
# 2         锌   zn   6%                            其中:zn1806 12%新合约   14%
# 3         铅   pb    6%                                              13%
# 4         镍   ni    6%                                              14%
# 5         锡   sn   6%                  其中:sn1712、1804、1806 12%新合约   13%
# 6        黄金   au   5%                            其中:au1709 10%新合约   13%
# 7        白银   ag    5%                                              14%
# 8       螺纹钢   rb    7%                                              15%
# 9        线材   wr   5%       其中:wr1706-1709、1711、1801-1806\n10%新合约    24%
# 10     热轧卷板   hc   6%                            其中:hc1806 12%新合约   14%
# 11      燃料油   fu   5%   其中:fu1707、1710、1712、1803、1805-1806 10%新合约    25%
# 12     石油沥青   bu    6%                                              14%
# 13       橡胶   ru   7%                            其中:ru1806 14%新合约   15%
# 14      黄大豆    a   5%                              其中:a1811 8%新合约    12%
# 15      黄豆二    b   4%                              其中:b1806 8%新合约    25%
# 16      胶合板   bb   5%              其中:bb1801-1803、1805-1806 8%新合约    25%
# 17       玉米    c    5%                                               12%
# 18     玉米淀粉   cs    5%                                               12%
# 19      纤维板   fb   5%              其中:fb1706-1707、1710-1806 8%新合约    25%
# 20      铁矿石    i   8%                              其中:i1806 8%新合约    16%
# 21       焦炭    j   8%                              其中:j1806 8%新合约    16%
# 22      鲜鸡蛋   jd   5%                           其中:jd1706 9%第一个涨停   13%
# 23       焦煤   jm   8%                        其中:jm1804、1806 8%新合约    16%
# 24      聚乙烯    l   5%                         其中:l1804、1806 8%新合约    12%
# 25       豆粕    m    5%                                               12%
# 26      棕榈油    p   5%                              其中:p1806 8%新合约    12%
# 27      聚丙烯   pp   5%                             其中:pp1806 8%新合约    12%
# 28     聚氯乙烯    v   5%                    其中:v1711、1803、1806 8%新合约    12%
# 29       豆油    y    5%                                               12%
# 30       棉花   CF    5%                                              12%
# 31       玻璃   FG    5%                                              13%
# 32       粳稻   JR   4%                   其中:JR1707、1803、1805 8%新合约   25%
# 33      晚籼稻   LR   4%              其中:LR1707、1801、1803、1805 8%新合约   25%
# 34       甲醇   MA   5%                            其中:MA1806 10%新合约   12%
# 35      菜籽油   OI    5%                                              12%
# 36       普麦   PM   4%                  其中:PM1711、1803、1805\n8%新合约   25%
# 37      早籼稻   RI   4%                   其中:RI1711、1803、1805 8%新合约   25%
# 38      菜籽粕   RM    5%                                              11%
# 39      油菜籽   RS   10%                                               25%
# 40       硅铁   SF   5%                  其中:SF1803-1804、1806 10%新合约   14%
# 41       锰硅   SM   6%            其中:SM1711、1803-1804、1806\n12%新合约   14%
# 42       白糖   SR    4%                                              10%
# 43   精对苯二甲酸   TA    5%                                              11%
# 44       强麦   WH    5%                                              11%
# 45      动力煤   ZC    6%                      其中:ZC1803、1806 12%新合约   14%
# 46  股指沪深300   IF   10%                                               22%
# 47   上证50指数   IH   10%                                               22%
# 48  中证500指数   IC   10%                                               32%
#
#                    Margin Comments
# 0                   其中:cu1707\n16%
# 1                    其中:al1707 15%
# 2                   其中:zn1707\n16%
# 3                   其中:pb1707\n15%
# 4   其中:ni1707 16% ni1709 16%持仓超36万
# 5                    其中:sn1707 15%
# 6                    其中:au1707 17%
# 7                    其中:ag1707 17%
# 8                    其中:rb1707 16%
# 9
# 10                   其中:hc1707 16%
# 11
# 12                   其中:bu1707 16%
# 13  其中:ru1707 16% ru1709 18%持仓超16万
# 14
# 15
# 16
# 17
# 18
# 19
# 20
# 21
# 22                   其中:jd1706 25%
# 23
# 24
# 25
# 26
# 27
# 28
# 29
# 30                   其中:CF1707 15%
# 31                   其中:FG1707 16%
# 32                   其中:JR1707 30%
# 33                   其中:LR1707 30%
# 34                   其中:MA1707 15%
# 35                   其中:OI1707 15%
# 36                   其中:PM1707 30%
# 37                   其中:RI1707 30%
# 38                   其中:RM1707 15%
# 39
# 40                   其中:SF1707 17%
# 41                   其中:SM1707 17%
# 42                   其中:SR1707 15%
# 43                   其中:TA1707 15%
# 44                   其中:WH1707 14%
# 45                   其中:ZC1707 16%
# 46
# 47
# 48                     其中:IC套保 22%

# %%
NewData.columns = ['first']

# %%
NewData = NewData[NewData['first'] != '']

# %%
NewData
# Out:
#        Name Tick Limit                                   Comments  \
# 0         铜   cu    6%
# 1         铝   al    6%
# 2         锌   zn    6%
# 3         铅   pb    6%
# 4         镍   ni    6%
# 5         锡   sn   6%                  其中:sn1712、1804、1806 12%新合约
# 6        黄金   au    5%
# 7        白银   ag    5%
# 8       螺纹钢   rb    7%
# 9        线材   wr   5%        其中:wr1707-1709、1711、1801-1806 10%新合约
# 10     热轧卷板   hc    6%
# 11      燃料油   fu   5%   其中:fu1707、1710、1712、1803、1805-1806 10%新合约
# 12     石油沥青   bu    6%
# 13       橡胶   ru    7%
# 14      黄大豆    a    5%
# 15      黄豆二    b   4%                              其中:b1806 8%新合约
# 16      胶合板   bb   5%              其中:bb1801-1803、1805-1806 8%新合约
# 17       玉米    c    5%
# 18     玉米淀粉   cs    5%
# 19      纤维板   fb   5%         其中:fb1707、1710-1712、1802-1806 8%新合约
# 20      铁矿石    i   8%                              其中:i1806 8%新合约
# 21       焦炭    j   8%               其中:j1708 11%第一个涨停 j1806 8%新合约
# 22      鲜鸡蛋   jd    5%
# 23       焦煤   jm   8%        其中:jm1708 11%第一个涨停 jm1804、1806 8%新合约
# 24      聚乙烯    l   5%                         其中:l1804、1806 8%新合约
# 25       豆粕    m    5%
# 26      棕榈油    p    5%
# 27      聚丙烯   pp   5%                             其中:pp1806 8%新合约
# 28     聚氯乙烯    v   5%                         其中:v1803、1806 8%新合约
# 29       豆油    y    5%
# 30       棉花   CF    5%
# 31       玻璃   FG   5%                          其中:FG1709 7%第一个涨停
# 32       粳稻   JR   4%                   其中:JR1707、1803、1805 8%新合约
# 33      晚籼稻   LR   4%              其中:LR1707、1801、1803、1805 8%新合约
# 34       甲醇   MA   5%                            其中:MA1806 10%新合约
# 35      菜籽油   OI    5%
# 36       普麦   PM   4%                   其中:PM1711、1803、1805 8%新合约
# 37      早籼稻   RI   4%                   其中:RI1711、1803、1805 8%新合约
# 38      菜籽粕   RM    5%
# 39      油菜籽   RS   10%
# 40       硅铁   SF   5%                  其中:SF1803-1804、1806 10%新合约
# 41       锰硅   SM   6%                  其中:SM1711、1804、1806 12%新合约
# 42       白糖   SR    4%
# 43   精对苯二甲酸   TA    5%
# 44       强麦   WH    7%
# 45      动力煤   ZC    6%                      其中:ZC1803、1806 12%新合约
# 46  股指沪深300   IF   10%
# 47   上证50指数   IH   10%
# 48  中证500指数   IC   10%
#
#    Reserve Rate                               Res_Comments
# 0          14%                    其中:cu1707 21% cu1708 16%
# 1          13%                    其中:al1707 20% al1708 15%
# 2          14%                    其中:zn1707 21% zn1708 16%
# 3          13%                    其中:pb1707 20% pb1708 15%
# 4          14%   其中:ni1707 21% ni1708 16% ni1709 16%持仓超36万
# 5          13%                    其中:sn1707 20% sn1708 15%
# 6          13%                    其中:au1707 22% au1708 17%
# 7          14%                    其中:ag1707 22% ag1708 17%
# 8          15%                    其中:rb1707 21% rb1708 16%
# 9           40%
# 10         14%                    其中:hc1707 21% hc1708 16%
# 11          40%
# 12         14%                    其中:bu1707 21% bu1708 16%
# 13         15%   其中:ru1707 21% ru1708 16% ru1709 18%持仓超16万
# 14         12%                                其中:a1707 25%
# 15         25%                                其中:b1707 40%
# 16          40%
# 17         12%                                其中:c1707 25%
# 18         12%                               其中:cs1707 25%
# 19          40%
# 20         16%                                其中:i1707 26%
# 21         16%                 其中:j1707 26% j1708 19%第一个涨停
# 22         13%                               其中:jd1707 25%
# 23         16%               其中:jm1707 26% jm1708 19%第一个涨停
# 24         12%                                其中:l1707 25%
# 25         12%                                其中:m1707 25%
# 26         12%                                其中:p1707 25%
# 27         12%                               其中:pp1707 25%
# 28         12%                                其中:v1707 25%
# 29         12%                                其中:y1707 25%
# 30         12%                               其中:CF1707 25%
# 31         13%               其中:FG1707 26% FG1709 15%第一个涨停
# 32         25%                               其中:JR1707 40%
# 33         25%                               其中:LR1707 40%
# 34         12%                               其中:MA1707 25%
# 35         12%                               其中:OI1707 25%
# 36         25%                               其中:PM1707 40%
# 37         25%                               其中:RI1707 40%
# 38         11%                               其中:RM1707 25%
# 39          40%
# 40         14%                               其中:SF1707 27%
# 41         14%                               其中:SM1707 27%
# 42         10%                               其中:SR1707 25%
# 43         11%                               其中:TA1707 25%
# 44          40%
# 45         14%                               其中:ZC1707 26%
# 46          22%
# 47          22%
# 48          32%                                其中:IC套保 22%

# %%
NewData['first'][0:10].str.splitlines()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-95-79b1d45f5573> in <module>()
# ----> 1 NewData['first'][0:10].str.splitlines()
#
# AttributeError: 'StringMethods' object has no attribute 'splitlines'

# %%
x1 = NewData[0]
location_df = NewData[0,'left','right'].apply(lambda x1: pd.Series(x1.split(':')))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\kinsly\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4433)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13742)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13696)()
#
# KeyError: (0, 'left', 'right')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-191-36c5f4cffad2> in <module>()
#       1 x1 = NewData[0]
# ----> 2 location_df = NewData[0,'left','right'].apply(lambda x1: pd.Series(x1.split(':')))
#
# C:\Users\kinsly\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# C:\Users\kinsly\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# C:\Users\kinsly\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# C:\Users\kinsly\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3541
#    3542             if not isnull(item):
# -> 3543                 loc = self.items.get_loc(item)
#    3544             else:
#    3545                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\Users\kinsly\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4433)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13742)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13696)()
#
# KeyError: (0, 'left', 'right')

# %%
NewData
# Out:
#          Name Tick Limit                                   Comments
# 0    铜          cu    6%
# 1    铝          al    6%
# 2    锌          zn    6%
# 3    铅          pb    6%
# 4    镍          ni    6%
# 5    锡          sn   6%                  其中:sn1712、1804、1806 12%新合约
# 6     黄金        au    5%
# 7     白银        ag    5%
# 8      螺纹钢      rb    7%
# 9     线  材      wr   5%        其中:wr1707-1709、1711、1801-1806 10%新合约
# 10      热轧卷板    hc    6%
# 11     燃料油      fu   5%   其中:fu1707、1710、1712、1803、1805-1806 10%新合约
# 12      石油沥青    bu    6%
# 13    橡  胶      ru    7%
# 14     黄大豆       a    5%
# 15     黄豆二       b   4%                              其中:b1806 8%新合约
# 16     胶合板      bb   5%              其中:bb1801-1803、1805-1806 8%新合约
# 17    玉  米       c    5%
# 18      玉米淀粉    cs    5%
# 19     纤维板      fb   5%         其中:fb1707、1710-1712、1802-1806 8%新合约
# 20     铁矿石       i   8%                              其中:i1806 8%新合约
# 21    焦  炭       j   8%               其中:j1708 11%第一个涨停 j1806 8%新合约
# 22     鲜鸡蛋      jd    5%
# 23    焦  煤      jm   8%        其中:jm1708 11%第一个涨停 jm1804、1806 8%新合约
# 24     聚乙烯       l   5%                         其中:l1804、1806 8%新合约
# 25    豆  粕       m    5%
# 26     棕榈油       p    5%
# 27     聚丙烯      pp   5%                             其中:pp1806 8%新合约
# 28      聚氯乙烯     v   5%                         其中:v1803、1806 8%新合约
# 29    豆  油       y    5%
# ..        ...  ...   ...                                        ...
# 72     焦  炭      j  16%                 其中:j1707 26% j1708 19%第一个涨停
# 73      鲜鸡蛋     jd  13%                               其中:jd1707 25%
# 74     焦  煤     jm  16%               其中:jm1707 26% jm1708 19%第一个涨停
# 75      聚乙烯      l  12%                                其中:l1707 25%
# 76     豆  粕      m  12%                                其中:m1707 25%
# 77      棕榈油      p  12%                                其中:p1707 25%
# 78      聚丙烯     pp  12%                               其中:pp1707 25%
# 79       聚氯乙烯    v  12%                                其中:v1707 25%
# 80     豆  油      y  12%                                其中:y1707 25%
# 81     棉  花     CF  12%                               其中:CF1707 25%
# 82     玻  璃     FG  13%               其中:FG1707 26% FG1709 15%第一个涨停
# 83     粳  稻     JR  25%                               其中:JR1707 40%
# 84      晚籼稻     LR  25%                               其中:LR1707 40%
# 85     甲  醇     MA  12%                               其中:MA1707 25%
# 86      菜籽油     OI  12%                               其中:OI1707 25%
# 87     普  麦     PM  25%                               其中:PM1707 40%
# 88      早籼稻     RI  25%                               其中:RI1707 40%
# 89      菜籽粕     RM  11%                               其中:RM1707 25%
# 90      油菜籽     RS   40%
# 91     硅  铁     SF  14%                               其中:SF1707 27%
# 92     锰  硅     SM  14%                               其中:SM1707 27%
# 93     白  糖     SR  10%                               其中:SR1707 25%
# 94    精对苯二甲酸    TA  11%                               其中:TA1707 25%
# 95     强  麦     WH   40%
# 96      动力煤     ZC  14%                               其中:ZC1707 26%
# 97   股指沪深300    IF   22%
# 98   上证50指数     IH   22%
# 99   中证500指数    IC   32%                                其中:IC套保 22%
# 100   年期国债      TF  2.2%
# 101    年期国债      T    3%
#
# [102 rows x 4 columns]

# %%
(NewData['Tick'].iloc[1])[:-2]
# Out:
# '铝       '
